# %%
import pandas as pd
df= pd.read_csv ('/im/IHME-GBD_2019_DATA-ff08d9bc-1.csv')
df1= pd.read_csv ('/im/IHME-GBD_2019_DATA-0bbd35c5-1.csv')

# %%
df.head()
# Out:
#   measure location     sex       age                           cause metric  \
# 0  Deaths    Samoa    Male  All Ages    Chronic respiratory diseases   Rate
# 1  Deaths    Samoa  Female  All Ages    Chronic respiratory diseases   Rate
# 2  Deaths    Samoa    Both  All Ages    Chronic respiratory diseases   Rate
# 3  Deaths    Samoa    Male  All Ages  Skin and subcutaneous diseases   Rate
# 4  Deaths    Samoa  Female  All Ages  Skin and subcutaneous diseases   Rate
#
#    year        val      upper      lower
# 0  2000  64.470214  81.808307  53.476793
# 1  2000  55.234399  77.883497  39.978647
# 2  2000  60.039961  76.013089  49.941986
# 3  2000   2.246741   3.467454   1.438979
# 4  2000   1.368385   1.945448   0.866099

# %%
df.tail()
# Out:
#        measure location     sex       age  \
# 257035  Deaths  Comoros  Female  All Ages
# 257036  Deaths  Comoros    Both  All Ages
# 257037  Deaths  Comoros    Male  All Ages
# 257038  Deaths  Comoros  Female  All Ages
# 257039  Deaths  Comoros    Both  All Ages
#
#                                           cause metric  year        val  \
# 257035  Neglected tropical diseases and malaria   Rate  2004  53.727176
# 257036  Neglected tropical diseases and malaria   Rate  2004  55.473969
# 257037             Chronic respiratory diseases   Rate  2004  26.083547
# 257038             Chronic respiratory diseases   Rate  2004  19.658170
# 257039             Chronic respiratory diseases   Rate  2004  22.849508
#
#             upper      lower
# 257035  92.205694  24.130322
# 257036  96.573472  24.780106
# 257037  32.912324  18.654426
# 257038  25.456633  14.278054
# 257039  27.877194  17.872866

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257040 entries, 0 to 257039
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   measure   257040 non-null  object
#  1   location  257040 non-null  object
#  2   sex       257040 non-null  object
#  3   age       257040 non-null  object
#  4   cause     257040 non-null  object
#  5   metric    257040 non-null  object
#  6   year      257040 non-null  int64
#  7   val       257040 non-null  float64
#  8   upper     257040 non-null  float64
#  9   lower     257040 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 19.6+ MB

# %%
df.describe(include = 'all')
# Out:
#        measure location     sex       age                         cause  \
# count   257040   257040  257040    257040                        257040
# unique       1      204       3         1                            21
# top     Deaths    Samoa    Male  All Ages  Chronic respiratory diseases
# freq    257040     1260   85680    257040                         12240
# mean       NaN      NaN     NaN       NaN                           NaN
# std        NaN      NaN     NaN       NaN                           NaN
# min        NaN      NaN     NaN       NaN                           NaN
# 25%        NaN      NaN     NaN       NaN                           NaN
# 50%        NaN      NaN     NaN       NaN                           NaN
# 75%        NaN      NaN     NaN       NaN                           NaN
# max        NaN      NaN     NaN       NaN                           NaN
#
#         metric           year            val          upper          lower
# ...

# %%
df.shape
# Out:
# (257040, 10)

# %%
df.dropna(inplace = True)

# %%
df.measure
# Out:
# 0         Deaths
# 1         Deaths
# 2         Deaths
# 3         Deaths
# 4         Deaths
#            ...
# 257035    Deaths
# 257036    Deaths
# 257037    Deaths
# 257038    Deaths
# 257039    Deaths
# Name: measure, Length: 257040, dtype: object

# %%
df.loc[100:120, 'location':'val']
# Out:
#                                   location     sex       age  \
# 100                              Indonesia  Female  All Ages
# 101                              Indonesia    Both  All Ages
# 102                             Azerbaijan    Male  All Ages
# 103                             Azerbaijan  Female  All Ages
# 104                             Azerbaijan    Both  All Ages
# 105  Democratic People's Republic of Korea    Male  All Ages
# 106  Democratic People's Republic of Korea  Female  All Ages
# 107  Democratic People's Republic of Korea    Both  All Ages
# 108                                  China    Male  All Ages
# 109                                  China  Female  All Ages
# 110                                  China    Both  All Ages
# 111                             Azerbaijan    Male  All Ages
# 112                             Azerbaijan  Female  All Ages
# 113                             Azerbaijan    Both  All Ages
# ...

# %%
df[(df['sex']=='Both') & (df['cause']== 'Cardiovascular diseases') & (df['year']==2019) & (df['val'] > 600)]
# Out:
#        measure             location   sex       age                    cause  \
# 199944  Deaths      North Macedonia  Both  All Ages  Cardiovascular diseases
# 201828  Deaths               Latvia  Both  All Ages  Cardiovascular diseases
# 203892  Deaths   Russian Federation  Both  All Ages  Cardiovascular diseases
# 205248  Deaths              Hungary  Both  All Ages  Cardiovascular diseases
# 207636  Deaths              Ukraine  Both  All Ages  Cardiovascular diseases
# 220377  Deaths              Georgia  Both  All Ages  Cardiovascular diseases
# 223428  Deaths              Romania  Both  All Ages  Cardiovascular diseases
# 223692  Deaths              Estonia  Both  All Ages  Cardiovascular diseases
# 224058  Deaths  Republic of Moldova  Both  All Ages  Cardiovascular diseases
# 224319  Deaths             Bulgaria  Both  All Ages  Cardiovascular diseases
# 230433  Deaths               Serbia  Both  All Ages  Cardiovascular diseases
# ...

# %%
cardio = df[(df['sex']=='Both') & (df['cause']== 'Cardiovascular diseases') & (df['year']==2019) & (df['val'] > 600)]

# %%
cardio.sort_values(by = ['val'], ascending = False)
# Out:
#        measure             location   sex       age                    cause  \
# 224319  Deaths             Bulgaria  Both  All Ages  Cardiovascular diseases
# 207636  Deaths              Ukraine  Both  All Ages  Cardiovascular diseases
# 201828  Deaths               Latvia  Both  All Ages  Cardiovascular diseases
# 220377  Deaths              Georgia  Both  All Ages  Cardiovascular diseases
# 232800  Deaths              Belarus  Both  All Ages  Cardiovascular diseases
# 223428  Deaths              Romania  Both  All Ages  Cardiovascular diseases
# 231075  Deaths            Lithuania  Both  All Ages  Cardiovascular diseases
# 230433  Deaths               Serbia  Both  All Ages  Cardiovascular diseases
# 203892  Deaths   Russian Federation  Both  All Ages  Cardiovascular diseases
# 199944  Deaths      North Macedonia  Both  All Ages  Cardiovascular diseases
# 205248  Deaths              Hungary  Both  All Ages  Cardiovascular diseases
# ...

# %%
df[df['cause'].str.contains('HIV')==True]
# Out:
#        measure                          location     sex       age  \
# 18      Deaths                   Solomon Islands    Male  All Ages
# 19      Deaths                   Solomon Islands  Female  All Ages
# 20      Deaths                   Solomon Islands    Both  All Ages
# 138     Deaths                         Indonesia    Male  All Ages
# 139     Deaths                         Indonesia  Female  All Ages
# ...        ...                               ...     ...       ...
# 256924  Deaths                            Tuvalu  Female  All Ages
# 256925  Deaths                            Tuvalu    Both  All Ages
# 256986  Deaths  Democratic Republic of the Congo    Male  All Ages
# 256987  Deaths  Democratic Republic of the Congo  Female  All Ages
# 256988  Deaths  Democratic Republic of the Congo    Both  All Ages
#
#                                                cause metric  year         val  \
# 18      HIV/AIDS and sexually transmitted infections   Rate  2000   21.364097
# ...

# %%
df['val_round'] = df['val'].round(decimals=1)
df
# Out:
#        measure location     sex       age  \
# 0       Deaths    Samoa    Male  All Ages
# 1       Deaths    Samoa  Female  All Ages
# 2       Deaths    Samoa    Both  All Ages
# 3       Deaths    Samoa    Male  All Ages
# 4       Deaths    Samoa  Female  All Ages
# ...        ...      ...     ...       ...
# 257035  Deaths  Comoros  Female  All Ages
# 257036  Deaths  Comoros    Both  All Ages
# 257037  Deaths  Comoros    Male  All Ages
# 257038  Deaths  Comoros  Female  All Ages
# 257039  Deaths  Comoros    Both  All Ages
#
#                                           cause metric  year        val  \
# 0                  Chronic respiratory diseases   Rate  2000  64.470214
# 1                  Chronic respiratory diseases   Rate  2000  55.234399
# 2                  Chronic respiratory diseases   Rate  2000  60.039961
# 3                Skin and subcutaneous diseases   Rate  2000   2.246741
# 4                Skin and subcutaneous diseases   Rate  2000   1.368385
# ...

# %%
df.rename(columns= {'val':'value'}, inplace = True)
df
# Out:
#        measure location     sex       age  \
# 0       Deaths    Samoa    Male  All Ages
# 1       Deaths    Samoa  Female  All Ages
# 2       Deaths    Samoa    Both  All Ages
# 3       Deaths    Samoa    Male  All Ages
# 4       Deaths    Samoa  Female  All Ages
# ...        ...      ...     ...       ...
# 257035  Deaths  Comoros  Female  All Ages
# 257036  Deaths  Comoros    Both  All Ages
# 257037  Deaths  Comoros    Male  All Ages
# 257038  Deaths  Comoros  Female  All Ages
# 257039  Deaths  Comoros    Both  All Ages
#
#                                           cause metric  year      value  \
# 0                  Chronic respiratory diseases   Rate  2000  64.470214
# 1                  Chronic respiratory diseases   Rate  2000  55.234399
# 2                  Chronic respiratory diseases   Rate  2000  60.039961
# 3                Skin and subcutaneous diseases   Rate  2000   2.246741
# 4                Skin and subcutaneous diseases   Rate  2000   1.368385
# ...

# %%
df.drop(['age'], axis = 1)
# Out:
#        measure location     sex                                    cause  \
# 0       Deaths    Samoa    Male             Chronic respiratory diseases
# 1       Deaths    Samoa  Female             Chronic respiratory diseases
# 2       Deaths    Samoa    Both             Chronic respiratory diseases
# 3       Deaths    Samoa    Male           Skin and subcutaneous diseases
# 4       Deaths    Samoa  Female           Skin and subcutaneous diseases
# ...        ...      ...     ...                                      ...
# 257035  Deaths  Comoros  Female  Neglected tropical diseases and malaria
# 257036  Deaths  Comoros    Both  Neglected tropical diseases and malaria
# 257037  Deaths  Comoros    Male             Chronic respiratory diseases
# 257038  Deaths  Comoros  Female             Chronic respiratory diseases
# 257039  Deaths  Comoros    Both             Chronic respiratory diseases
#
#        metric  year      value      upper      lower  val_round
# ...

# %%
df['value'].mean()
# Out:
# 38.800590204586626

# %%
df['cause'].unique()
# Out:
# array(['Chronic respiratory diseases', 'Skin and subcutaneous diseases',
#        'Transport injuries', 'Unintentional injuries',
#        'Musculoskeletal disorders', 'Other non-communicable diseases',
#        'HIV/AIDS and sexually transmitted infections',
#        'Respiratory infections and tuberculosis', 'Enteric infections',
#        'Other infectious diseases', 'Maternal and neonatal disorders',
#        'Substance use disorders', 'Nutritional deficiencies', 'Neoplasms',
#        'Neurological disorders', 'Mental disorders',
#        'Self-harm and interpersonal violence', 'Digestive diseases',
#        'Neglected tropical diseases and malaria',
#        'Cardiovascular diseases', 'Diabetes and kidney diseases'],
#       dtype=object)

# %%
df[df['year']==2019].nlargest(5, 'value')
# Out:
#        measure  location     sex       age                    cause metric  \
# 224318  Deaths  Bulgaria  Female  All Ages  Cardiovascular diseases   Rate
# 224319  Deaths  Bulgaria    Both  All Ages  Cardiovascular diseases   Rate
# 224317  Deaths  Bulgaria    Male  All Ages  Cardiovascular diseases   Rate
# 207635  Deaths   Ukraine  Female  All Ages  Cardiovascular diseases   Rate
# 207636  Deaths   Ukraine    Both  All Ages  Cardiovascular diseases   Rate
#
#         year        value        upper       lower  val_round
# 224318  2019  1177.059351  1389.915309  990.814152     1177.1
# 224319  2019  1140.933052  1349.387220  960.194209     1140.9
# 224317  2019  1102.642773  1312.249719  922.635865     1102.6
# 207635  2019  1035.300219  1223.150810  858.748304     1035.3
# 207636  2019  1020.326176  1166.207717  890.091470     1020.3

# %%
df[(df['year']==2019)&(df['location'].isin(['Belarus']))]
# Out:
#        measure location     sex       age                   cause metric  \
# 201745  Deaths  Belarus    Male  All Ages               Neoplasms   Rate
# 201746  Deaths  Belarus  Female  All Ages               Neoplasms   Rate
# 201747  Deaths  Belarus    Both  All Ages               Neoplasms   Rate
# 201748  Deaths  Belarus    Male  All Ages  Neurological disorders   Rate
# 201749  Deaths  Belarus  Female  All Ages  Neurological disorders   Rate
# ...        ...      ...     ...       ...                     ...    ...
# 232814  Deaths  Belarus  Female  All Ages      Transport injuries   Rate
# 232815  Deaths  Belarus    Both  All Ages      Transport injuries   Rate
# 232828  Deaths  Belarus    Male  All Ages  Unintentional injuries   Rate
# 232829  Deaths  Belarus  Female  All Ages  Unintentional injuries   Rate
# 232830  Deaths  Belarus    Both  All Ages  Unintentional injuries   Rate
#
#         year       value       upper       lower  val_round
# ...

# %%
df.groupby('cause').agg('mean')
# Out:
#                                                 year       value       upper  \
# cause
# Cardiovascular diseases                       2009.5  244.849189  272.303719
# Chronic respiratory diseases                  2009.5   31.818755   38.654844
# Diabetes and kidney diseases                  2009.5   47.226334   54.621903
# Digestive diseases                            2009.5   34.127663   40.322534
# Enteric infections                            2009.5   27.374869   41.591667
# HIV/AIDS and sexually transmitted infections  2009.5   41.961014   57.746888
# Maternal and neonatal disorders               2009.5   37.557121   45.650166
# Mental disorders                              2009.5    0.003640    0.005843
# Musculoskeletal disorders                     2009.5    1.192664    1.657964
# Neglected tropical diseases and malaria       2009.5   19.971543   34.743890
# Neoplasms                                     2009.5  127.104386  141.409473
# ...

# %%
df.groupby('cause').agg({'value' : ['mean', 'median']})
# Out:
#                                                    value
#                                                     mean      median
# cause
# Cardiovascular diseases                       244.849189  196.303826
# Chronic respiratory diseases                   31.818755   26.189078
# Diabetes and kidney diseases                   47.226334   35.326735
# Digestive diseases                             34.127663   32.318203
# Enteric infections                             27.374869    4.586162
# HIV/AIDS and sexually transmitted infections   41.961014    4.771283
# Maternal and neonatal disorders                37.557121   17.731659
# Mental disorders                                0.003640    0.000616
# Musculoskeletal disorders                       1.192664    0.740399
# Neglected tropical diseases and malaria        19.971543    0.371168
# Neoplasms                                     127.104386   88.808665
# Neurological disorders                         25.430591   17.136037
# ...

# %%
df_cause = df.groupby('cause').agg({'value' : ['mean', 'median']})
df_cause['value']['mean'].sort_values(ascending = False)
# Out:
# cause
# Cardiovascular diseases                         244.849189
# Neoplasms                                       127.104386
# Respiratory infections and tuberculosis          63.475924
# Diabetes and kidney diseases                     47.226334
# HIV/AIDS and sexually transmitted infections     41.961014
# Maternal and neonatal disorders                  37.557121
# Digestive diseases                               34.127663
# Chronic respiratory diseases                     31.818755
# Enteric infections                               27.374869
# Neurological disorders                           25.430591
# Unintentional injuries                           24.371415
# Self-harm and interpersonal violence             21.545159
# Neglected tropical diseases and malaria          19.971543
# Other non-communicable diseases                  19.209209
# Transport injuries                               18.432300
# Other infectious diseases                        16.805678
# ...

# %%
df_gender = df.groupby (['cause', 'sex']).agg({'value':['mean','median']})
df_gender
# Out:
#                                           value
#                                            mean      median
# cause                        sex
# Cardiovascular diseases      Both    245.038277  199.178194
#                              Female  242.429336  181.537109
#                              Male    247.079954  204.731125
# Chronic respiratory diseases Both     31.783867   27.341307
#                              Female   27.003046   21.051406
# ...                                         ...         ...
# Transport injuries           Female    9.329241    7.783497
#                              Male     27.497411   25.001762
# Unintentional injuries       Both     24.338395   21.899341
#                              Female   16.590452   14.334211
#                              Male     32.185398   28.135601
#
# [63 rows x 2 columns]

# %%
df_gender.xs('Transport injuries', level = 'cause')
# Out:
#             value
#              mean     median
# sex
# Both    18.470248  16.414021
# Female   9.329241   7.783497
# Male    27.497411  25.001762

# %%
df_pivot = df.pivot_table(values='value', index = 'location', columns = 'cause', aggfunc ='mean',margins=True, fill_value=None)
df_pivot
# Out:
# cause           Cardiovascular diseases  Chronic respiratory diseases  \
# location
# Afghanistan                  202.375232                     26.283434
# Albania                      350.065948                     23.643664
# Algeria                      211.215757                     16.638977
# American Samoa               182.311074                     37.029051
# Andorra                      174.338254                     40.992289
# ...                                 ...                           ...
# Viet Nam                     223.841941                     36.347300
# Yemen                        165.911423                     18.345432
# Zambia                        99.046369                     15.704447
# Zimbabwe                     116.440730                     19.825721
# All                          244.849189                     31.818755
#
# cause           Diabetes and kidney diseases  Digestive diseases  \
# location
# ...

# %%
df_pivot.loc['Belarus', 'HIV/AIDS and sexually transmitted infections']
# Out:
# 3.253055555834314

# %%
df_pivot = df.pivot_table(values='value', index = ['location','year'], columns = 'cause', aggfunc ='mean',margins=True, fill_value=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df[(df['location']=='Belarus')&(df['cause']=='Chronic respiratory diseases')
   &(df['sex']=='Both')].pivot_table(values='val',index='year',columns='sex', 
                                     aggfunc='mean',fill_value=None, margins=False, dropna=True).plot(kind='line')
plt.ylabel('death per 100 000 peoople')
plt.title('Chronic respiratory diseases in Belarus')
# Out:
# Text(0.5, 1.0, 'Chronic respiratory diseases in Belarus')

# %%
df[(df['sex'].isin(['Male','Female']))&(df['year']==2012)].pivot_table(values='val',index='cause',
                                                                       columns='sex', aggfunc='mean',fill_value=None, 
                                                                       margins=False, dropna=True).plot(kind='bar')
plt.ylabel('death per 100 000 peoople')
plt.title('Death by sex')
# Out:
# Text(0.5, 1.0, 'Death by sex')

# %%
df1.head(10)
# Out:
#                                   measure location   sex       age  \
# 0  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 1  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 2  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 3  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 4  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 5  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 6  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 7  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 8  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
# 9  DALYs (Disability-Adjusted Life Years)   Global  Both  All ages
#
#         cause   metric  year           val         upper         lower
# 0  All causes   Number  2001  2.637936e+09  2.839662e+09  2.453899e+09
# 1  All causes  Percent  2001  1.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
df1.rename(columns = {'val': 'daly_val', 'upper':'daly_upper', 'lower':'daly_lower'},inplace=True)

# %%
df_all=pd.merge(df,df1, on = ['location', 'sex', 'age', 'cause', 'metric', 'year'], how = 'inner')

# %%
df_all.head(10)
# Out:
# Empty DataFrame
# Columns: [measure_x, location, sex, age, cause, metric, year, val, upper, lower, measure_y, daly_val, daly_upper, daly_lower]
# Index: []

# %%
df_all.shape
# Out:
# (0, 14)
